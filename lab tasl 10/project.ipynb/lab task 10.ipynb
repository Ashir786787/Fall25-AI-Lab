# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io

# %%
data = pd.read_csv('Mobile-Price-Prediction-cleaned_data.csv')
data.shape
# Out:
# (807, 8)

# %%
data.head()
# Out:
#    Ratings  RAM    ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  \
# 0      4.3  4.0  128.0         6.00           48       13.0           4000
# 1      3.4  6.0   64.0         4.50           48       12.0           4000
# 2      4.3  4.0    4.0         4.50           64       16.0           4000
# 3      4.4  6.0   64.0         6.40           48       15.0           3800
# 4      4.5  6.0  128.0         6.18           35       15.0           3800
#
#    Price
# 0  24999
# 1  15999
# 2  15000
# 3  18999
# 4  18999

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 807 entries, 0 to 806
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ratings        807 non-null    float64
#  1   RAM            807 non-null    float64
#  2   ROM            807 non-null    float64
#  3   Mobile_Size    807 non-null    float64
#  4   Primary_Cam    807 non-null    int64
#  5   Selfi_Cam      807 non-null    float64
#  6   Battery_Power  807 non-null    int64
#  7   Price          807 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 50.6 KB

# %%
data.columns.tolist()
# Out:
# ['Ratings',
#  'RAM',
#  'ROM',
#  'Mobile_Size',
#  'Primary_Cam',
#  'Selfi_Cam',
#  'Battery_Power',
#  'Price']

# %%
rows, cols = data.shape
print(f"Rows: {rows}")
print(f"Columns: {cols}")
# Out:
# Rows: 807
# Columns: 8

# %%
data.describe()
# Out:
#           Ratings         RAM         ROM  Mobile_Size  Primary_Cam  \
# count  807.000000  807.000000  807.000000   807.000000   807.000000
# mean     4.112639    5.941760   64.390335     5.620660    47.821561
# std      0.367830    2.056359   53.868626     3.957409    11.155916
# min      2.800000    0.000000    2.000000     2.000000     5.000000
# 25%      3.900000    6.000000   32.000000     4.500000    48.000000
# 50%      4.100000    6.000000   32.000000     4.770000    48.000000
# 75%      4.400000    6.000000   64.000000     6.300000    48.000000
# max      4.800000   12.000000  256.000000    44.000000    64.000000
#
#         Selfi_Cam  Battery_Power          Price
# count  807.000000     807.000000     807.000000
# mean     8.868649    3278.859975   14269.167286
# std      4.547254     937.628801   23092.739983
# min      0.000000    1020.000000     479.000000
# 25%      8.000000    3000.000000     984.000000
# 50%      8.000000    3000.000000    1699.000000
# 75%     12.000000    3800.000000   18994.500000
# max     23.000000    6000.000000  153000.000000

# %%
null_values = data.isnull().sum()
print(null_values)
print("\nTotal:", null_values.sum())
# Out:
# Ratings          0
# RAM              0
# ROM              0
# Mobile_Size      0
# Primary_Cam      0
# Selfi_Cam        0
# Battery_Power    0
# Price            0
# dtype: int64
#
# Total: 0

# %%
data.dtypes
# Out:
# Ratings          float64
# RAM              float64
# ROM              float64
# Mobile_Size      float64
# Primary_Cam        int64
# Selfi_Cam        float64
# Battery_Power      int64
# Price              int64
# dtype: object

# %%
# Robustly handle missing/renamed columns (use alternatives or show available columns)
col_candidates = ['make', 'brand', 'manufacturer', 'maker']
col_map = {c.lower().strip(): c for c in data.columns}
found = None
for cand in col_candidates:
    if cand in col_map:
        found = col_map[cand]
        break
if found is None:
    print("Column 'make' not found. Available columns:")
    print(data.columns.tolist())
else:
    print(data[found].unique())
    print("\nUnique makes:", data[found].nunique())
    print("\n" + "="*50)
    print("\nFuel types:")
    if 'fuel_type' in col_map:
        print(data[col_map['fuel_type']].unique())
    elif 'fuel' in col_map:
        print(data[col_map['fuel']].unique())
    else:
        print("No 'fuel_type' column found.")
    print("\n" + "="*50)
    print("\nTransmission types:")
    if 'transmission' in col_map:
        print(data[col_map['transmission']].unique())
    else:
        print("No 'transmission' column found.")
# Out:
# Column 'make' not found. Available columns:
# ['Ratings', 'RAM', 'ROM', 'Mobile_Size', 'Primary_Cam', 'Selfi_Cam', 'Battery_Power', 'Price']

# %%
data.sample(10)
# Out:
#      Ratings  RAM    ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  \
# 195      4.1  6.0   32.0         4.50           48       15.0           3000
# 737      4.1  8.0   64.0         4.54           64        8.0           2500
# 51       3.8  6.0   32.0         4.54           48        8.0           2800
# 515      4.5  6.0   32.0         4.50           64       15.0           3000
# 392      3.9  6.0   32.0         4.50           64       12.0           2000
# 151      3.8  6.0   32.0        44.00           48        8.0           3000
# 343      3.6  6.0   64.0         4.50           48        8.0           3500
# 764      4.5  6.0  128.0         6.39           48       13.0           4030
# 528      3.5  6.0   32.0         4.50           64        8.0           1050
# 387      4.1  1.0   16.0         5.00            5        2.0           2500
#
#      Price
# 195   1099
# 737   1199
# 51    1299
# 515    649
# 392    749
# 151    890
# 343    629
# 764  24999
# 528    799
# 387   5049

# %%
data.tail()
# Out:
#      Ratings   RAM   ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  \
# 802      3.8   6.0  32.0         4.54           48       12.0           2800
# 803      4.1   8.0  64.0         4.54           64        8.0           2500
# 804      4.4   3.0  32.0         6.20           48        1.0           3800
# 805      3.7  10.0  32.0         4.50           64        8.0           3500
# 806      3.5   6.0  32.0         4.50           64       15.0           1050
#
#      Price
# 802   1299
# 803   1390
# 804   9790
# 805    799
# 806    799

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 807 entries, 0 to 806
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ratings        807 non-null    float64
#  1   RAM            807 non-null    float64
#  2   ROM            807 non-null    float64
#  3   Mobile_Size    807 non-null    float64
#  4   Primary_Cam    807 non-null    int64
#  5   Selfi_Cam      807 non-null    float64
#  6   Battery_Power  807 non-null    int64
#  7   Price          807 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 50.6 KB

# %%
data.columns.tolist()
# Out:
# ['Ratings',
#  'RAM',
#  'ROM',
#  'Mobile_Size',
#  'Primary_Cam',
#  'Selfi_Cam',
#  'Battery_Power',
#  'Price']

# %%
rows, cols = data.shape
print(f"Rows: {rows}")
print(f"Columns: {cols}")
# Out:
# Rows: 807
# Columns: 8

# %%
data.describe()
# Out:
#           Ratings         RAM         ROM  Mobile_Size  Primary_Cam  \
# count  807.000000  807.000000  807.000000   807.000000   807.000000
# mean     4.112639    5.941760   64.390335     5.620660    47.821561
# std      0.367830    2.056359   53.868626     3.957409    11.155916
# min      2.800000    0.000000    2.000000     2.000000     5.000000
# 25%      3.900000    6.000000   32.000000     4.500000    48.000000
# 50%      4.100000    6.000000   32.000000     4.770000    48.000000
# 75%      4.400000    6.000000   64.000000     6.300000    48.000000
# max      4.800000   12.000000  256.000000    44.000000    64.000000
#
#         Selfi_Cam  Battery_Power          Price
# count  807.000000     807.000000     807.000000
# mean     8.868649    3278.859975   14269.167286
# std      4.547254     937.628801   23092.739983
# min      0.000000    1020.000000     479.000000
# 25%      8.000000    3000.000000     984.000000
# 50%      8.000000    3000.000000    1699.000000
# 75%     12.000000    3800.000000   18994.500000
# max     23.000000    6000.000000  153000.000000

# %%
null_values = data.isnull().sum()
print(null_values)
print("\nTotal:", null_values.sum())
# Out:
# Ratings          0
# RAM              0
# ROM              0
# Mobile_Size      0
# Primary_Cam      0
# Selfi_Cam        0
# Battery_Power    0
# Price            0
# dtype: int64
#
# Total: 0

# %%
data.dtypes
# Out:
# Ratings          float64
# RAM              float64
# ROM              float64
# Mobile_Size      float64
# Primary_Cam        int64
# Selfi_Cam        float64
# Battery_Power      int64
# Price              int64
# dtype: object

# %%
data.sample(10)
# Out:
#      Ratings  RAM    ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  \
# 621      4.2  6.0   32.0         4.54           48       15.0           2500
# 114      3.7  4.0   40.0         4.58           48        8.0           3800
# 788      4.5  6.0  128.0         6.39           48       13.0           3800
# 400      3.8  6.0   32.0         4.77           48       15.0           3000
# 660      4.4  4.0  128.0         6.53           48        2.0           3500
# 627      4.1  6.0   32.0         4.54           48       20.0           3500
# 79       3.9  6.0   64.0         4.54           48        8.0           3600
# 17       4.5  8.0  128.0         6.70           64        1.0           4700
# 685      4.4  8.0  128.0         6.70           48        8.0           3000
# 521      3.4  4.0   64.0         5.50           48        5.0           3000
#
#      Price
# 621   1259
# 114   1799
# 788  24999
# 400    959
# 660  16490
# 627   3399
# 79    1799
# 17   77999
# 685  40900
# 521  13999

# %%
print("Checking for missing values...")
missing_data = data.isnull().sum()
print("Missing values per column:")
print(missing_data)
print("\nTotal missing values:", missing_data.sum())
# Out:
# Checking for missing values...
# Missing values per column:
# Ratings          0
# RAM              0
# ROM              0
# Mobile_Size      0
# Primary_Cam      0
# Selfi_Cam        0
# Battery_Power    0
# Price            0
# dtype: int64
#
# Total missing values: 0

# %%
print(f"Shape before: {data.shape}")
data = data.dropna()
print(f"Shape after: {data.shape}")
# Out:
# Shape before: (807, 8)
# Shape after: (807, 8)

# %%
float_cols = data.select_dtypes(include=['float64']).columns
print("Columns with float datatype:")
print(float_cols.tolist())
# Out:
# Columns with float datatype:
# ['Ratings', 'RAM', 'ROM', 'Mobile_Size', 'Selfi_Cam']

# %%
for col in float_cols:
    data[col] = data[col].astype(int)

print("Conversion completed")
print(data.dtypes)
# Out:
# Conversion completed
# Ratings          int64
# RAM              int64
# ROM              int64
# Mobile_Size      int64
# Primary_Cam      int64
# Selfi_Cam        int64
# Battery_Power    int64
# Price            int64
# dtype: object

# %%
print("Final data shape:", data.shape)
print("\nData types after preprocessing:")
print(data.dtypes)
print("\nNull values after preprocessing:")
print(data.isnull().sum().sum())
# Out:
# Final data shape: (807, 8)
#
# Data types after preprocessing:
# Ratings          int64
# RAM              int64
# ROM              int64
# Mobile_Size      int64
# Primary_Cam      int64
# Selfi_Cam        int64
# Battery_Power    int64
# Price            int64
# dtype: object
#
# Null values after preprocessing:
# 0
